# %%
import pandas as pd
import numpy as np

# %%
allbiz = pd.read_csv("/home/datalab/nfs/deepfm/data/allbiz/tovslova-allbz-WEIG__30-07__FULL.csv")

# %%
allbiz
# Out:
#      Товарное слово в проме Категории_allbiz_step_3_CAT1  \
# 0       транспортная_услуга         Логистические услуги
# 1       транспортная_услуга         Логистические услуги
# 2       транспортная_услуга         Логистические услуги
# 3       транспортная_услуга               Бытовые услуги
# 4       транспортная_услуга         Логистические услуги
# ...                     ...                          ...
# 9678                  полис             Страховые услуги
# 9679            медматериал          Медицинская техника
# 9680            медматериал          Медицинская техника
# 9681                счетчик         Приборы и автоматика
# 9682                счетчик         Приборы и автоматика
#
#                           Категории_allbiz_step_3_CAT2  \
# 0                  Услуги городского электротранспорта
# 1                    Транспортно-экспедиторские услуги
# 2                     Перевозка грузов автотранспортом
# ...
